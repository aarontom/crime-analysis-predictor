# %%
import pandas as pd

# %%
df = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %%
df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230  \
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 798237  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 798238  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 798239  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 798240  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 798241  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd
# ...

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
print(df["Crm Cd Desc"].value_counts()[:50])
# Out:
# Crm Cd Desc
# VEHICLE - STOLEN                                            85323
# BATTERY - SIMPLE ASSAULT                                    63456
# THEFT OF IDENTITY                                           50920
# BURGLARY FROM VEHICLE                                       49044
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     48753
# BURGLARY                                                    48554
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              45927
# THEFT PLAIN - PETTY ($950 & UNDER)                          40693
# INTIMATE PARTNER - SIMPLE ASSAULT                           40259
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)             30872
# THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)         29201
# ROBBERY                                                     27362
# THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD    25855
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)                    21505
# ...
